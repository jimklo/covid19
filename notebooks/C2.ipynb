# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
import re
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_dir = Path('../data/CSSEGISandData/COVID-19/csse_covid_19_data/csse_covid_19_time_series')

# %%
all_data = []

for data_file in data_dir.glob('*.csv'):
    print(data_file.stem)
    file_type = data_file.stem.split('-')[-1]
    df = pd.read_csv(data_file)
    df.loc[:,'health_status'] = file_type
    all_data.append(df)
#     display(df)

df_all = pd.concat(all_data, ignore_index=True, sort=False)
df_all = df_all.set_index(['Province/State', 'Country/Region', 'Lat', 'Long'])
df_all = df_all.pivot(columns='health_status')
df_all = df_all.sort_index(level=[1,0]).T.sort_index(level=[0,1])
df_all
# Out:
# time_series_19-covid-Recovered
# time_series_19-covid-Deaths
# time_series_19-covid-Confirmed
# Province/State                NaN                                          \
# Country/Region        Afghanistan   Albania   Algeria   Andorra Argentina
# Lat                       33.0000   41.1533   28.0339   42.5063  -38.4161
# Long                     65.0000   20.1683   1.6596    1.5218   -63.6167
#         health_status
# 1/22/20 Confirmed               0         0         0         0         0
#         Deaths                  0         0         0         0         0
#         Recovered               0         0         0         0         0
# 1/23/20 Confirmed               0         0         0         0         0
#         Deaths                  0         0         0         0         0
# ...                           ...       ...       ...       ...       ...
# 3/8/20  Deaths                  0         0         0         0         1
#         Recovered               0         0         0         0         0
# 3/9/20  Confirmed               4         2        20         1        12
#         Deaths                  0         0         0         0         1
#         Recovered               0         0         0         0         0
#
# Province/State                  From Diamond Princess New South Wales  \
# Country/Region          Armenia             Australia       Australia
# Lat                     40.0691               35.4437        -33.8688
# Long                   45.0382               139.6380        151.2093
#         health_status
# 1/22/20 Confirmed             0                     0               0
#         Deaths                0                     0               0
#         Recovered             0                     0               0
# 1/23/20 Confirmed             0                     0               0
#         Deaths                0                     0               0
# ...                         ...                   ...             ...
# 3/8/20  Deaths                0                     0               2
#         Recovered             0                     0               4
# 3/9/20  Confirmed             1                     0              48
#         Deaths                0                     0               2
#         Recovered             0                     0               4
#
# Province/State        Northern Territory Queensland  ... Wisconsin  \
# Country/Region                 Australia  Australia  ...        US
# Lat                             -12.4634   -28.0167  ...   44.2685
# Long                            130.8456   153.4000  ... -89.6165
#         health_status                                ...
# 1/22/20 Confirmed                      0          0  ...         0
#         Deaths                         0          0  ...         0
#         Recovered                      0          0  ...         0
# 1/23/20 Confirmed                      0          0  ...         0
#         Deaths                         0          0  ...         0
# ...                                  ...        ...  ...       ...
# 3/8/20  Deaths                         0          0  ...         0
#         Recovered                      0          8  ...         0
# 3/9/20  Confirmed                      0         15  ...         0
#         Deaths                         0          0  ...         0
#         Recovered                      0          8  ...         0
#
# Province/State        Worcester, MA   Wyoming Yolo County, CA       NaN  \
# Country/Region                   US        US              US   Ukraine
# Lat                         42.4097   42.7560         38.7646   48.3794
# Long                      -71.8571  -107.3025       -121.9018  31.1656
#         health_status
# 1/22/20 Confirmed                 0         0               0         0
#         Deaths                    0         0               0         0
#         Recovered                 0         0               0         0
# 1/23/20 Confirmed                 0         0               0         0
#         Deaths                    0         0               0         0
# ...                             ...       ...             ...       ...
# 3/8/20  Deaths                    0         0               0         0
#         Recovered                 0         0               0         0
# 3/9/20  Confirmed                 0         0               1         1
#         Deaths                    0         0               0         0
#         Recovered                 0         0               0         0
#
# Province/State                             Channel Islands      Gibraltar  \
# Country/Region        United Arab Emirates  United Kingdom United Kingdom
# Lat                                24.0000         49.3723        36.1408
# Long                              54.0000        -2.3644        -5.3536
#         health_status
# 1/22/20 Confirmed                        0               0              0
#         Deaths                           0               0              0
#         Recovered                        0               0              0
# 1/23/20 Confirmed                        0               0              0
#         Deaths                           0               0              0
# ...                                    ...             ...            ...
# 3/8/20  Deaths                           0               0              0
#         Recovered                        7               0              0
# 3/9/20  Confirmed                       45               0              1
#         Deaths                           0               0              0
#         Recovered                        7               0              0
#
# Province/State                    UK       NaN
# Country/Region        United Kingdom   Vietnam
# Lat                          55.3781   16.0000
# Long                       -3.4360    108.0000
#         health_status
# 1/22/20 Confirmed                  0         0
#         Deaths                     0         0
#         Recovered                  0         0
# 1/23/20 Confirmed                  0         2
#         Deaths                     0         0
# ...                              ...       ...
# 3/8/20  Deaths                     3         0
#         Recovered                 18        16
# 3/9/20  Confirmed                321        30
#         Deaths                     4         0
#         Recovered                 18        16
#
# [153 rows x 406 columns]

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]
